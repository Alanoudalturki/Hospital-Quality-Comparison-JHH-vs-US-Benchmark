# %%
#Import libraries
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
#Import files =9 seperate datasets
data_2015=pd.read_csv('/ReadmissionRate/2015.csv', encoding = 'unicode_escape',low_memory=False)
data_2016=pd.read_csv('/ReadmissionRate/2016.csv', encoding = 'unicode_escape',low_memory=False)
data_2017=pd.read_csv('/ReadmissionRate/2017.csv', encoding = 'unicode_escape',low_memory=False)
data_2018=pd.read_csv('/ReadmissionRate/2018.csv', encoding = 'unicode_escape',low_memory=False)
data_2019=pd.read_csv('/ReadmissionRate/2019.csv', encoding = 'unicode_escape',low_memory=False)
data_2021=pd.read_csv('/ReadmissionRate/2021.csv', encoding = 'unicode_escape',low_memory=False)
data_2022=pd.read_csv('/ReadmissionRate/2022.csv', encoding = 'unicode_escape',low_memory=False)
data_2023=pd.read_csv('/ReadmissionRate/2023.csv', encoding = 'unicode_escape',low_memory=False)

# %%
data_2019
# Out:
#       Facility ID                                      Facility Name  \
# 0          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 2          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 3          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 4          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                                ...
# 54077      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 54078      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 54079      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 54080      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 54081      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 0                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 1                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 2                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 3                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 4                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 54077  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 54078  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 54079  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 54080  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 54081  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name    Phone Number          Measure ID  \
# 0         HOUSTON  (334) 793-8701         EDAC_30_AMI
# 1         HOUSTON  (334) 793-8701          EDAC_30_HF
# 2         HOUSTON  (334) 793-8701          EDAC_30_PN
# 3         HOUSTON  (334) 793-8701               OP_32
# 4         HOUSTON  (334) 793-8701        READM_30_AMI
# ...           ...             ...                 ...
# 54077      TRAVIS  (512) 654-6100       READM_30_COPD
# 54078      TRAVIS  (512) 654-6100         READM_30_HF
# 54079      TRAVIS  (512) 654-6100   READM_30_HIP_KNEE
# 54080      TRAVIS  (512) 654-6100  READM_30_HOSP_WIDE
# 54081      TRAVIS  (512) 654-6100         READM_30_PN
#
#                                             Measure Name  \
# 0         Hospital return days for heart attack patients
# 1        Hospital return days for heart failure patients
# 2            Hospital return days for pneumonia patients
# 3      Rate of unplanned hospital visits after colono...
# 4      Acute Myocardial Infarction (AMI) 30-Day Readm...
# ...                                                  ...
# 54077  Rate of readmission for chronic obstructive pu...
# 54078         Heart failure (HF) 30-Day Readmission Rate
# 54079     Rate of readmission after hip/knee replacement
# 54080  Rate of readmission after discharge from hospi...
# 54081             Pneumonia (PN) 30-Day Readmission Rate
#
#                             Compared to National    Denominator  \
# 0                Average Days per 100 Discharges            742
# 1      More Days Than Average per 100 Discharges           1114
# 2                Average Days per 100 Discharges            604
# 3            No Different than the National Rate            205
# 4            No Different Than the National Rate            742
# ...                                          ...            ...
# 54077                              Not Available  Not Available
# 54078                              Not Available  Not Available
# 54079                              Not Available  Not Available
# 54080                              Not Available  Not Available
# 54081                              Not Available  Not Available
#
#                Score Lower Estimate Higher Estimate  Footnote  Start Date  \
# 0               -0.8          -11.6            10.6       NaN  07/01/2015
# 1               17.8            4.5            31.5       NaN  07/01/2015
# 2               -7.8          -21.3               6       NaN  07/01/2015
# 3               13.9             10            19.2       NaN  01/01/2017
# 4               16.2           14.0            18.5       NaN  07/01/2015
# ...              ...            ...             ...       ...         ...
# 54077  Not Available  Not Available   Not Available       5.0  07/01/2015
# 54078  Not Available  Not Available   Not Available       5.0  07/01/2015
# 54079  Not Available  Not Available   Not Available       5.0  07/01/2015
# 54080  Not Available  Not Available   Not Available       5.0  07/01/2017
# 54081  Not Available  Not Available   Not Available       5.0  07/01/2015
#
#          End Date
# 0      06/30/2018
# 1      06/30/2018
# 2      06/30/2018
# 3      12/31/2017
# 4      06/30/2018
# ...           ...
# 54077  06/30/2018
# 54078  06/30/2018
# 54079  06/30/2018
# 54080  06/30/2018
# 54081  06/30/2018
#
# [54082 rows x 18 columns]

# %%
#step 3 select spesific columns

#2015
Data2015_filtered=pd.DataFrame(data_2015, columns =['Provider ID','Hospital Name','Measure Name',
                                                    'Measure ID', 'Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

#2016
Data2016_filtered=pd.DataFrame(data_2016, columns =['Provider ID','Hospital Name','Measure Name','Measure ID',
                                                     'Denominator', 'Score','Measure Start Date','Measure End Date'])

#2017
Data2017_filtered=pd.DataFrame(data_2017, columns =['Provider ID','Hospital Name','Measure Name',
                                                    'Measure ID', 'Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

#2018
Data2018_filtered=pd.DataFrame(data_2018, columns =['Provider ID','Hospital Name','Measure Name',
                                                    'Measure ID', 'Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

#2019
Data2019_filtered=pd.DataFrame(data_2019, columns =['Facility ID','Facility Name','Measure Name',
                                                    'Measure ID','Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])


#2021
Data2021_filtered=pd.DataFrame(data_2021, columns =['Facility ID','Facility Name','Measure Name',
                                                    'Measure ID','Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

#2022
Data2022_filtered=pd.DataFrame(data_2022, columns =['Facility ID','Facility Name','Measure Name',
                                                    'Measure ID','Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

#2023
Data2023_filtered=pd.DataFrame(data_2023, columns =['Facility ID','Facility Name','Measure Name',
                                                    'Measure ID','Denominator', 'Score','Measure Start Date',
                                                    'Measure End Date'])

# %%
Data2023_filtered
# Out:
#       Facility ID                     Facility Name  \
# 0          010001   SOUTHEAST HEALTH MEDICAL CENTER
# 1          010001   SOUTHEAST HEALTH MEDICAL CENTER
# 2          010001   SOUTHEAST HEALTH MEDICAL CENTER
# 3          010001   SOUTHEAST HEALTH MEDICAL CENTER
# 4          010001   SOUTHEAST HEALTH MEDICAL CENTER
# ...           ...                               ...
# 67867      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 67868      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 67869      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 67870      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 67871      670314  ST MICHAELS MEDICAL HOSPITAL LLC
#
#                                             Measure Name          Measure ID  \
# 0         Hospital return days for heart attack patients         EDAC_30_AMI
# 1        Hospital return days for heart failure patients          EDAC_30_HF
# 2            Hospital return days for pneumonia patients          EDAC_30_PN
# 3      Rate of unplanned hospital visits after colono...               OP_32
# 4      Rate of inpatient admissions for patients rece...           OP_35_ADM
# ...                                                  ...                 ...
# 67867  Rate of readmission for chronic obstructive pu...       READM_30_COPD
# 67868         Heart failure (HF) 30-Day Readmission Rate         READM_30_HF
# 67869     Rate of readmission after hip/knee replacement   READM_30_HIP_KNEE
# 67870  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 67871             Pneumonia (PN) 30-Day Readmission Rate         READM_30_PN
#
#          Denominator          Score  Measure Start Date  Measure End Date
# 0                319            1.9                 NaN               NaN
# 1                755           21.8                 NaN               NaN
# 2                436           -1.5                 NaN               NaN
# 3                254           14.1                 NaN               NaN
# 4                214           10.2                 NaN               NaN
# ...              ...            ...                 ...               ...
# 67867  Not Available  Not Available                 NaN               NaN
# 67868  Not Available  Not Available                 NaN               NaN
# 67869  Not Available  Not Available                 NaN               NaN
# 67870  Not Available  Not Available                 NaN               NaN
# 67871  Not Available  Not Available                 NaN               NaN
#
# [67872 rows x 8 columns]

# %%
#Step 6: Replacing ‘Not Available’ entry
# Replace "Not Available"


Data2015_filtered ['Score']=pd.to_numeric(Data2015_filtered['Score'],errors= 'coerce')
Data2015_filtered = Data2015_filtered.replace(np.nan,0, regex =True )


Data2016_filtered ['Score']=pd.to_numeric(Data2016_filtered['Score'],errors= 'coerce')
Data2016_filtered = Data2016_filtered.replace(np.nan,0, regex =True )


Data2017_filtered ['Score']=pd.to_numeric(Data2017_filtered['Score'],errors= 'coerce')
Data2017_filtered = Data2017_filtered.replace(np.nan,0, regex =True )


Data2018_filtered ['Score']=pd.to_numeric(Data2018_filtered['Score'],errors= 'coerce')
Data2018_filtered = Data2018_filtered.replace(np.nan,0, regex =True )


Data2019_filtered ['Score']=pd.to_numeric(Data2019_filtered['Score'],errors= 'coerce')
Data2019_filtered = Data2019_filtered.replace(np.nan,0, regex =True )


Data2021_filtered ['Score']=pd.to_numeric(Data2021_filtered['Score'],errors= 'coerce')
Data2021_filtered = Data2021_filtered.replace(np.nan,0, regex =True )


Data2022_filtered ['Score']=pd.to_numeric(Data2022_filtered['Score'],errors= 'coerce')
Data2022_filtered = Data2022_filtered.replace(np.nan,0, regex =True )


Data2023_filtered ['Score']=pd.to_numeric(Data2023_filtered['Score'],errors= 'coerce')
Data2023_filtered = Data2023_filtered.replace(np.nan,0, regex =True )

# %%
#Step 6: Replacing ‘Not Available’ entry
# Replace "Not Available"


Data2015_filtered ['Denominator']=pd.to_numeric(Data2015_filtered['Denominator'],errors= 'coerce')
Data2015_filtered = Data2015_filtered.replace(np.nan,0, regex =True )


Data2016_filtered ['Denominator']=pd.to_numeric(Data2016_filtered['Denominator'],errors= 'coerce')
Data2016_filtered = Data2016_filtered.replace(np.nan,0, regex =True )


Data2017_filtered ['Denominator']=pd.to_numeric(Data2017_filtered['Denominator'],errors= 'coerce')
Data2017_filtered = Data2017_filtered.replace(np.nan,0, regex =True )


Data2018_filtered ['Denominator']=pd.to_numeric(Data2018_filtered['Denominator'],errors= 'coerce')
Data2018_filtered = Data2018_filtered.replace(np.nan,0, regex =True )


Data2019_filtered ['Denominator']=pd.to_numeric(Data2019_filtered['Denominator'],errors= 'coerce')
Data2019_filtered = Data2019_filtered.replace(np.nan,0, regex =True )


Data2021_filtered ['Denominator']=pd.to_numeric(Data2021_filtered['Denominator'],errors= 'coerce')
Data2021_filtered = Data2021_filtered.replace(np.nan,0, regex =True )


Data2022_filtered ['Denominator']=pd.to_numeric(Data2022_filtered['Denominator'],errors= 'coerce')
Data2022_filtered = Data2022_filtered.replace(np.nan,0, regex =True )


Data2023_filtered ['Denominator']=pd.to_numeric(Data2023_filtered['Denominator'],errors= 'coerce')
Data2023_filtered = Data2023_filtered.replace(np.nan,0, regex =True )

# %%
##Step 6a: View updated column


print ("/033[1m"+ '2015 Score Value float Types' +"/033[0m" )
print (Data2015_filtered['Score'].head(10))

print ("/033[1m"+ '2016 Score  Value float Types' +"/033[0m" )
print (Data2016_filtered['Score'].head(10))

print ("/033[1m"+ '2017 Score Value float Types' +"/033[0m" )
print (Data2017_filtered['Score'].head(10))

print ("/033[1m"+ '2018 Score Value float Types'+"/033[0m" )
print (Data2018_filtered['Score'].head(10))

print ("/033[1m"+ '2019 Score Value float Types' +"/033[0m" )
print (Data2019_filtered['Score'].head(10))

print ("/033[1m"+ '2021 Score Value float Types' +"/033[0m" )
print (Data2021_filtered['Score'].head(10))

print ("/033[1m"+ '2022 Score Value float Types' +"/033[0m" )
print (Data2022_filtered['Score'].head(10))

print ("/033[1m"+ '2023 Score Value float Types' +"/033[0m" )
print (Data2023_filtered['Score'].head(10))
# Out:
# /0332015 Score Value float Types/033
# 0    12.2
# 1     3.7
# 2     8.8
# 3    12.6
# 4    11.6
# 5    15.3
# 6    17.4
# 7    15.9
# 8    22.0
# 9    21.0
# Name: Score, dtype: float64
# /0332016 Score  Value float Types/033
# 0    12.5
# 1     4.2
# 2     9.3
# 3    12.4
# 4    15.5
# 5    15.4
# 6    16.5
# 7    15.1
# 8    21.1
# 9    21.4
# Name: Score, dtype: float64
# /0332017 Score Value float Types/033
# 0     4.20
# 1    13.40
# 2     3.50
# 3     9.70
# 4    11.40
# 5    15.40
# 6    16.10
# 7     0.89
# 8    10.30
# 9     3.76
# Name: Score, dtype: float64
# /0332018 Score Value float Types/033
# 0    -5.9
# 1    17.1
# 2     8.4
# 3    14.8
# 4    15.9
# 5    14.9
# 6    19.4
# 7    21.8
# 8     4.3
# 9    15.4
# Name: Score, dtype: float64
# /0332019 Score Value float Types/033
# 0    -0.8
# 1    17.8
# 2    -7.8
# 3    13.9
# 4    16.2
# 5    15.6
# 6    19.8
# 7    22.6
# 8     4.7
# 9    15.4
# Name: Score, dtype: float64
# /0332021 Score Value float Types/033
# 0     6.5
# 1    16.1
# 2    -7.1
# 3    14.1
# 4    11.3
# 5     6.7
# 6     0.9
# 7    16.2
# 8    13.5
# 9    21.2
# Name: Score, dtype: float64
# /0332022 Score Value float Types/033
# 0     1.9
# 1    21.8
# 2    -1.5
# 3    14.5
# 4     7.4
# 5     4.3
# 6     0.8
# 7    14.9
# 8    11.7
# 9    19.9
# Name: Score, dtype: float64
# /0332023 Score Value float Types/033
# 0     1.9
# 1    21.8
# 2    -1.5
# 3    14.1
# 4    10.2
# 5     4.7
# 6     1.0
# 7    14.9
# 8    11.7
# 9    19.9
# Name: Score, dtype: float64

# %%
##Step 7: Apply conditions to data frame
##CEDARS-SINAI MEDICAL CENTER, LOS ANGELES (50625)
#CLEVELAND CLINIC (100289)
#UCLA MEDICAL CENTER, LOS ANGELES (50262)
#NEW YORK-PRESBYTERIAN HOSPITAL NEW YORK. (330101)
#MASSACHUSETTS GENERAL HOSPITAL, BOSTON (220071)
#JOHNS HOPKINS HOSPITAL(210009)

pids = ['210009','50625','100289','50262','330101','220071']

Data2015_filtered2 = pd.DataFrame(Data2015_filtered[(Data2015_filtered['Provider ID'].isin(pids))])
print("\033[1m" +'2015 Filtered Dataset' + "\033[0m")
print(Data2015_filtered2.head(3))

Data2016_filtered2 = pd.DataFrame(Data2016_filtered[(Data2016_filtered['Provider ID'].isin(pids))])
print("\033[1m" +'2016 Filtered Dataset' + "\033[0m")
print(Data2016_filtered2.head(3))

Data2017_filtered2 = pd.DataFrame(Data2017_filtered[(Data2017_filtered['Provider ID'].isin(pids))])
print("\033[1m" +'2017 Filtered Dataset' + "\033[0m")
print(Data2017_filtered2.head(3))
      
Data2018_filtered2 = pd.DataFrame(Data2018_filtered[(Data2018_filtered['Provider ID'].isin(pids))])
print("\033[1m" +'2018 Filtered Dataset' + "\033[0m")
print(Data2018_filtered2.head(3))

Data2019_filtered2 = pd.DataFrame(Data2019_filtered[(Data2019_filtered['Facility ID'].isin(pids))])
print("\033[1m" +'2019 Filtered Dataset' + "\033[0m")
print(Data2019_filtered2.head(3))

Data2021_filtered2 = pd.DataFrame(Data2021_filtered[(Data2021_filtered['Facility ID'].isin(pids))])
print("\033[1m" +'2021 Filtered Dataset' + "\033[0m")
print(Data2021_filtered2.head(3))

Data2022_filtered2 = pd.DataFrame(Data2022_filtered[(Data2022_filtered['Facility ID'].isin(pids))])
print("\033[1m" +'2022 Filtered Dataset' + "\033[0m")
print(Data2022_filtered2.head(3))

Data2023_filtered2 = pd.DataFrame(Data2023_filtered[(Data2023_filtered['Facility ID'].isin(pids))])
print("\033[1m" +'2023 Filtered Dataset' + "\033[0m")
print(Data2023_filtered2.head(3))
# Out:
# 2015 Filtered Dataset
#       Provider ID              Hospital Name  \
# 12404      100289  CLEVELAND CLINIC HOSPITAL
# 12405      100289  CLEVELAND CLINIC HOSPITAL
# 12406      100289  CLEVELAND CLINIC HOSPITAL
#
#                                             Measure Name    Measure ID  \
# 12404  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 12405                                Death rate for CABG  MORT_30_CABG
# 12406  Death rate for chronic obstructive pulmonary d...  MORT_30_COPD
#
#        Denominator  Score Measure Start Date Measure End Date
# 12404         78.0   14.1         07/01/2011       06/30/2014
# 12405         43.0    3.0         07/01/2011       06/30/2014
# 12406        135.0    7.3         07/01/2011       06/30/2014
# 2016 Filtered Dataset
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Measure Name, Measure ID, Denominator, Score, Measure Start Date, Measure End Date]
# Index: []
# 2017 Filtered Dataset
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Measure Name, Measure ID, Denominator, Score, Measure Start Date, Measure End Date]
# Index: []
# 2018 Filtered Dataset
#      Provider ID                         Hospital Name  \
# 4632       50262  RONALD REAGAN U C L A MEDICAL CENTER
# 4633       50262  RONALD REAGAN U C L A MEDICAL CENTER
# 4634       50262  RONALD REAGAN U C L A MEDICAL CENTER
#
#                                          Measure Name   Measure ID  \
# 4632   Hospital return days for heart attack patients  EDAC_30_AMI
# 4633  Hospital return days for heart failure patients   EDAC_30_HF
# 4634      Hospital return days for pneumonia patients   EDAC_30_PN
#
#       Denominator  Score Measure Start Date Measure End Date
# 4632        214.0    5.4           7/1/2014        6/30/2017
# 4633        343.0   43.7           7/1/2014        6/30/2017
# 4634        374.0   80.0           7/1/2014        6/30/2017
# 2019 Filtered Dataset
#       Facility ID              Facility Name  \
# 10031      100289  CLEVELAND CLINIC HOSPITAL
# 10032      100289  CLEVELAND CLINIC HOSPITAL
# 10033      100289  CLEVELAND CLINIC HOSPITAL
#
#                                           Measure Name   Measure ID  \
# 10031   Hospital return days for heart attack patients  EDAC_30_AMI
# 10032  Hospital return days for heart failure patients   EDAC_30_HF
# 10033      Hospital return days for pneumonia patients   EDAC_30_PN
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 10031        100.0  -25.6                 0.0               0.0
# 10032        370.0   35.7                 0.0               0.0
# 10033        322.0   26.1                 0.0               0.0
# 2021 Filtered Dataset
#       Facility ID              Facility Name  \
# 12628      100289  CLEVELAND CLINIC HOSPITAL
# 12629      100289  CLEVELAND CLINIC HOSPITAL
# 12630      100289  CLEVELAND CLINIC HOSPITAL
#
#                                           Measure Name   Measure ID  \
# 12628   Hospital return days for heart attack patients  EDAC_30_AMI
# 12629  Hospital return days for heart failure patients   EDAC_30_HF
# 12630      Hospital return days for pneumonia patients   EDAC_30_PN
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12628         81.0    7.7                 0.0               0.0
# 12629        384.0   33.1                 0.0               0.0
# 12630        283.0   36.8                 0.0               0.0
# 2022 Filtered Dataset
#       Facility ID              Facility Name  \
# 12628      100289  CLEVELAND CLINIC HOSPITAL
# 12629      100289  CLEVELAND CLINIC HOSPITAL
# 12630      100289  CLEVELAND CLINIC HOSPITAL
#
#                                           Measure Name   Measure ID  \
# 12628   Hospital return days for heart attack patients  EDAC_30_AMI
# 12629  Hospital return days for heart failure patients   EDAC_30_HF
# 12630      Hospital return days for pneumonia patients   EDAC_30_PN
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12628         77.0   34.4                 0.0               0.0
# 12629        396.0   18.2                 0.0               0.0
# 12630        231.0   22.5                 0.0               0.0
# 2023 Filtered Dataset
#       Facility ID              Facility Name  \
# 12642      100289  CLEVELAND CLINIC HOSPITAL
# 12643      100289  CLEVELAND CLINIC HOSPITAL
# 12644      100289  CLEVELAND CLINIC HOSPITAL
#
#                                           Measure Name   Measure ID  \
# 12642   Hospital return days for heart attack patients  EDAC_30_AMI
# 12643  Hospital return days for heart failure patients   EDAC_30_HF
# 12644      Hospital return days for pneumonia patients   EDAC_30_PN
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12642         77.0   34.4                 0.0               0.0
# 12643        396.0   18.2                 0.0               0.0
# 12644        231.0   22.5                 0.0               0.0

# %%
Data2016_filtered2
# Out:
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Measure Name, Measure ID, Denominator, Score, Measure Start Date, Measure End Date]
# Index: []

# %%
Data2019_filtered2
# Out:
#       Facility ID                                      Facility Name  \
# 10031      100289                          CLEVELAND CLINIC HOSPITAL
# 10032      100289                          CLEVELAND CLINIC HOSPITAL
# 10033      100289                          CLEVELAND CLINIC HOSPITAL
# 10034      100289                          CLEVELAND CLINIC HOSPITAL
# 10035      100289                          CLEVELAND CLINIC HOSPITAL
# 10036      100289                          CLEVELAND CLINIC HOSPITAL
# 10037      100289                          CLEVELAND CLINIC HOSPITAL
# 10038      100289                          CLEVELAND CLINIC HOSPITAL
# 10039      100289                          CLEVELAND CLINIC HOSPITAL
# 10040      100289                          CLEVELAND CLINIC HOSPITAL
# 10041      100289                          CLEVELAND CLINIC HOSPITAL
# 21696      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21697      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21698      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21699      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21700      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21701      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21702      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21703      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21704      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21705      210009                        JOHNS HOPKINS HOSPITAL, THE
# 21706      210009                        JOHNS HOPKINS HOSPITAL, THE
# 22496      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22497      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22498      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22499      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22500      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22501      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22502      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22503      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22504      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22505      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 22506      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 32242      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32243      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32244      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32245      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32246      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32247      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32248      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32249      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32250      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32251      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
# 32252      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
#
#                                             Measure Name          Measure ID  \
# 10031     Hospital return days for heart attack patients         EDAC_30_AMI
# 10032    Hospital return days for heart failure patients          EDAC_30_HF
# 10033        Hospital return days for pneumonia patients          EDAC_30_PN
# 10034  Rate of unplanned hospital visits after colono...               OP_32
# 10035  Acute Myocardial Infarction (AMI) 30-Day Readm...        READM_30_AMI
# 10036                       Rate of readmission for CABG       READM_30_CABG
# 10037  Rate of readmission for chronic obstructive pu...       READM_30_COPD
# 10038         Heart failure (HF) 30-Day Readmission Rate         READM_30_HF
# 10039     Rate of readmission after hip/knee replacement   READM_30_HIP_KNEE
# 10040  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 10041             Pneumonia (PN) 30-Day Readmission Rate         READM_30_PN
# 21696     Hospital return days for heart attack patients         EDAC_30_AMI
# 21697    Hospital return days for heart failure patients          EDAC_30_HF
# 21698        Hospital return days for pneumonia patients          EDAC_30_PN
# 21699  Rate of unplanned hospital visits after colono...               OP_32
# 21700  Acute Myocardial Infarction (AMI) 30-Day Readm...        READM_30_AMI
# 21701                       Rate of readmission for CABG       READM_30_CABG
# 21702  Rate of readmission for chronic obstructive pu...       READM_30_COPD
# 21703         Heart failure (HF) 30-Day Readmission Rate         READM_30_HF
# 21704     Rate of readmission after hip/knee replacement   READM_30_HIP_KNEE
# 21705  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 21706             Pneumonia (PN) 30-Day Readmission Rate         READM_30_PN
# 22496     Hospital return days for heart attack patients         EDAC_30_AMI
# 22497    Hospital return days for heart failure patients          EDAC_30_HF
# 22498        Hospital return days for pneumonia patients          EDAC_30_PN
# 22499  Rate of unplanned hospital visits after colono...               OP_32
# 22500  Acute Myocardial Infarction (AMI) 30-Day Readm...        READM_30_AMI
# 22501                       Rate of readmission for CABG       READM_30_CABG
# 22502  Rate of readmission for chronic obstructive pu...       READM_30_COPD
# 22503         Heart failure (HF) 30-Day Readmission Rate         READM_30_HF
# 22504     Rate of readmission after hip/knee replacement   READM_30_HIP_KNEE
# 22505  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 22506             Pneumonia (PN) 30-Day Readmission Rate         READM_30_PN
# 32242     Hospital return days for heart attack patients         EDAC_30_AMI
# 32243    Hospital return days for heart failure patients          EDAC_30_HF
# 32244        Hospital return days for pneumonia patients          EDAC_30_PN
# 32245  Rate of unplanned hospital visits after colono...               OP_32
# 32246  Acute Myocardial Infarction (AMI) 30-Day Readm...        READM_30_AMI
# 32247                       Rate of readmission for CABG       READM_30_CABG
# 32248  Rate of readmission for chronic obstructive pu...       READM_30_COPD
# 32249         Heart failure (HF) 30-Day Readmission Rate         READM_30_HF
# 32250     Rate of readmission after hip/knee replacement   READM_30_HIP_KNEE
# 32251  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 32252             Pneumonia (PN) 30-Day Readmission Rate         READM_30_PN
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 10031        100.0  -25.6                 0.0               0.0
# 10032        370.0   35.7                 0.0               0.0
# 10033        322.0   26.1                 0.0               0.0
# 10034        971.0   15.7                 0.0               0.0
# 10035        100.0   14.6                 0.0               0.0
# 10036         73.0   12.1                 0.0               0.0
# 10037        113.0   19.2                 0.0               0.0
# 10038        370.0   23.9                 0.0               0.0
# 10039        783.0    2.8                 0.0               0.0
# 10040       2681.0   16.7                 0.0               0.0
# 10041        322.0   18.6                 0.0               0.0
# 21696        374.0   34.7                 0.0               0.0
# 21697        852.0   14.9                 0.0               0.0
# 21698        464.0   45.6                 0.0               0.0
# 21699        404.0   15.2                 0.0               0.0
# 21700        374.0   17.7                 0.0               0.0
# 21701        361.0   14.8                 0.0               0.0
# 21702        262.0   18.2                 0.0               0.0
# 21703        852.0   20.8                 0.0               0.0
# 21704          0.0    0.0                 0.0               0.0
# 21705       6681.0   16.0                 0.0               0.0
# 21706        464.0   18.0                 0.0               0.0
# 22496        927.0   28.6                 0.0               0.0
# 22497       2025.0   28.2                 0.0               0.0
# 22498       1563.0   28.1                 0.0               0.0
# 22499       3069.0   13.5                 0.0               0.0
# 22500        927.0   17.1                 0.0               0.0
# 22501        447.0   10.9                 0.0               0.0
# 22502        670.0   17.4                 0.0               0.0
# 22503       2025.0   20.7                 0.0               0.0
# 22504       1477.0    3.9                 0.0               0.0
# 22505      12474.0   15.9                 0.0               0.0
# 22506       1563.0   17.0                 0.0               0.0
# 32242       1082.0    3.7                 0.0               0.0
# 32243       2367.0   29.9                 0.0               0.0
# 32244       2364.0   39.8                 0.0               0.0
# 32245       1626.0   16.6                 0.0               0.0
# 32246       1082.0   15.1                 0.0               0.0
# 32247        538.0   14.4                 0.0               0.0
# 32248        810.0   20.6                 0.0               0.0
# 32249       2367.0   22.8                 0.0               0.0
# 32250        739.0    4.4                 0.0               0.0
# 32251      18079.0   15.9                 0.0               0.0
# 32252       2364.0   16.5                 0.0               0.0

# %%
pids = ['READM_30_HOSP_WIDE']

Data2015_filtered3 = pd.DataFrame(Data2015_filtered2[(Data2015_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2015 Filtered Dataset' + "\033[0m")
print(Data2015_filtered3.head(3))

Data2016_filtered3 = pd.DataFrame(Data2016_filtered2[(Data2016_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2016 Filtered Dataset' + "\033[0m")
print(Data2016_filtered3.head(3))

Data2017_filtered3 = pd.DataFrame(Data2017_filtered2[(Data2017_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2017 Filtered Dataset' + "\033[0m")
print(Data2017_filtered3.head(3))
      
Data2018_filtered3 = pd.DataFrame(Data2018_filtered2[(Data2018_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2018 Filtered Dataset' + "\033[0m")
print(Data2018_filtered3.head(3))

Data2019_filtered3 = pd.DataFrame(Data2019_filtered2[(Data2019_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2019 Filtered Dataset' + "\033[0m")
print(Data2019_filtered3.head(3))

Data2021_filtered3 = pd.DataFrame(Data2021_filtered2[(Data2021_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2021 Filtered Dataset' + "\033[0m")
print(Data2021_filtered3.head(3))

Data2022_filtered3 = pd.DataFrame(Data2022_filtered2[(Data2022_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2022 Filtered Dataset' + "\033[0m")
print(Data2022_filtered3.head(3))

Data2023_filtered3 = pd.DataFrame(Data2023_filtered2[(Data2023_filtered2['Measure ID'].isin(pids))])
print("\033[1m" +'2023 Filtered Dataset' + "\033[0m")
print(Data2023_filtered3.head(3))
# Out:
# 2015 Filtered Dataset
#       Provider ID                   Hospital Name  \
# 12415      100289       CLEVELAND CLINIC HOSPITAL
# 26821      210009     JOHNS HOPKINS HOSPITAL, THE
# 27787      220071  MASSACHUSETTS GENERAL HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 12415  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 26821  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 27787  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score Measure Start Date Measure End Date
# 12415       2429.0   16.7         07/01/2013       06/30/2014
# 26821       6845.0   17.8         07/01/2013       06/30/2014
# 27787      12515.0   16.5         07/01/2013       06/30/2014
# 2016 Filtered Dataset
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Measure Name, Measure ID, Denominator, Score, Measure Start Date, Measure End Date]
# Index: []
# 2017 Filtered Dataset
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, Measure Name, Measure ID, Denominator, Score, Measure Start Date, Measure End Date]
# Index: []
# 2018 Filtered Dataset
#       Provider ID                         Hospital Name  \
# 4641        50262  RONALD REAGAN U C L A MEDICAL CENTER
# 5985        50625           CEDARS-SINAI MEDICAL CENTER
# 10593      100289             CLEVELAND CLINIC HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 4641   30-Day Hospital-Wide All-Cause Unplanned Readm...  READM_30_HOSP_WIDE
# 5985   30-Day Hospital-Wide All-Cause Unplanned Readm...  READM_30_HOSP_WIDE
# 10593  30-Day Hospital-Wide All-Cause Unplanned Readm...  READM_30_HOSP_WIDE
#
#        Denominator  Score Measure Start Date Measure End Date
# 4641        3324.0   16.0           7/1/2016        6/30/2017
# 5985       13957.0   14.9           7/1/2016        6/30/2017
# 10593       2609.0   17.2           7/1/2016        6/30/2017
# 2019 Filtered Dataset
#       Facility ID                   Facility Name  \
# 10040      100289       CLEVELAND CLINIC HOSPITAL
# 21705      210009     JOHNS HOPKINS HOSPITAL, THE
# 22505      220071  MASSACHUSETTS GENERAL HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 10040  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 21705  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 22505  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 10040       2681.0   16.7                 0.0               0.0
# 21705       6681.0   16.0                 0.0               0.0
# 22505      12474.0   15.9                 0.0               0.0
# 2021 Filtered Dataset
#       Facility ID                   Facility Name  \
# 12640      100289       CLEVELAND CLINIC HOSPITAL
# 27312      210009     JOHNS HOPKINS HOSPITAL, THE
# 28320      220071  MASSACHUSETTS GENERAL HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 12640  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 27312  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 28320  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12640       1437.0   17.5                 0.0               0.0
# 27312       2689.0   15.4                 0.0               0.0
# 28320       5407.0   16.7                 0.0               0.0
# 2022 Filtered Dataset
#       Facility ID                   Facility Name  \
# 12640      100289       CLEVELAND CLINIC HOSPITAL
# 27326      210009     JOHNS HOPKINS HOSPITAL, THE
# 28320      220071  MASSACHUSETTS GENERAL HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 12640  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 27326  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 28320  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12640       2685.0   16.8                 0.0               0.0
# 27326       5533.0   14.8                 0.0               0.0
# 28320      11170.0   15.5                 0.0               0.0
# 2023 Filtered Dataset
#       Facility ID                   Facility Name  \
# 12654      100289       CLEVELAND CLINIC HOSPITAL
# 27340      210009     JOHNS HOPKINS HOSPITAL, THE
# 28334      220071  MASSACHUSETTS GENERAL HOSPITAL
#
#                                             Measure Name          Measure ID  \
# 12654  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 27340  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 28334  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 12654       2685.0   16.8                 0.0               0.0
# 27340       5533.0   14.8                 0.0               0.0
# 28334      11170.0   15.5                 0.0               0.0

# %%
Data2019_filtered3
# Out:
#       Facility ID                                      Facility Name  \
# 10040      100289                          CLEVELAND CLINIC HOSPITAL
# 21705      210009                        JOHNS HOPKINS HOSPITAL, THE
# 22505      220071                     MASSACHUSETTS GENERAL HOSPITAL
# 32251      330101  NEW YORK-PRESBYTERIAN HOSPITAL-NEW YORK WEILL ...
#
#                                             Measure Name          Measure ID  \
# 10040  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 21705  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 22505  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
# 32251  Rate of readmission after discharge from hospi...  READM_30_HOSP_WIDE
#
#        Denominator  Score  Measure Start Date  Measure End Date
# 10040       2681.0   16.7                 0.0               0.0
# 21705       6681.0   16.0                 0.0               0.0
# 22505      12474.0   15.9                 0.0               0.0
# 32251      18079.0   15.9                 0.0               0.0

# %%
#Average score of Comp.

Avg_2015= ((Data2015_filtered3['Denominator'].iloc[1:4].dot
            (Data2015_filtered3['Score'].iloc[1:4])).sum())/Data2015_filtered3['Denominator'].iloc[1:4].sum()

Avg_2016= ((Data2016_filtered3['Denominator'].iloc[1:4].dot
            (Data2016_filtered3['Score'].iloc[1:4])).sum())/Data2016_filtered3['Denominator'].iloc[1:4].sum()

Avg_2017= ((Data2017_filtered3['Denominator'].iloc[1:4].dot
            (Data2017_filtered3['Score'].iloc[1:4])).sum())/Data2017_filtered3['Denominator'].iloc[1:4].sum()

Avg_2018= ((Data2018_filtered3['Denominator'].iloc[1:4].dot
            (Data2018_filtered3['Score'].iloc[1:4])).sum())/Data2018_filtered3['Denominator'].iloc[1:4].sum()

Avg_2019= ((Data2019_filtered3['Denominator'].iloc[1:4].dot
            (Data2019_filtered3['Score'].iloc[1:4])).sum())/Data2019_filtered3['Denominator'].iloc[1:4].sum()

Avg_2021= ((Data2021_filtered3['Denominator'].iloc[1:4].dot
            (Data2021_filtered3['Score'].iloc[1:4])).sum())/Data2021_filtered3['Denominator'].iloc[1:4].sum()

Avg_2022= ((Data2022_filtered3['Denominator'].iloc[1:4].dot
            (Data2022_filtered3['Score'].iloc[1:4])).sum())/Data2022_filtered3['Denominator'].iloc[1:4].sum()

Avg_2023= ((Data2023_filtered3['Denominator'].iloc[1:4].dot
            (Data2023_filtered3['Score'].iloc[1:4])).sum())/Data2023_filtered3['Denominator'].iloc[1:4].sum()
# Out:
# /var/folders/cz/h8q7ysq15_b618tft_42rgmh0000gn/T/ipykernel_3789/426336513.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   Avg_2016= ((Data2016_filtered3['Denominator'].iloc[1:4].dot
# /var/folders/cz/h8q7ysq15_b618tft_42rgmh0000gn/T/ipykernel_3789/426336513.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   Avg_2017= ((Data2017_filtered3['Denominator'].iloc[1:4].dot

# %%
#Average score of Comp
print ('2015:',Avg_2015)
print ('2018:',Avg_2018)
print ('2019:',Avg_2019)
print ('2021:',Avg_2021)
print ('2022:',Avg_2022)
print ('2023:',Avg_2023)
# Out:
# 2015: 16.36299370564486
# 2018: 15.53769184856753
# 2019: 15.917943277649458
# 2021: 15.618971545695684
# 2022: 14.948019709349467
# 2023: 14.948019709349467

# %%
##Step 8: Average Satisfaction at JOHNS HOPKINS HOSPITAL
#Calculate average satisfaction at JH Hosp across all time periods
hosp = ['210009']

Data2015_JH = pd.DataFrame(Data2015_filtered3[(Data2015_filtered3['Provider ID'].isin(hosp))])
avgsatis_JH_2015 = Data2015_JH['Score'].mean()

Data2016_JH = pd.DataFrame(Data2016_filtered3[(Data2016_filtered3['Provider ID'].isin(hosp))])
avgsatis_JH_2016 = Data2016_JH['Score'].mean()

Data2017_JH = pd.DataFrame(Data2017_filtered3[(Data2017_filtered3['Provider ID'].isin(hosp))])
avgsatis_JH_2017 = Data2017_JH['Score'].mean()

Data2018_JH = pd.DataFrame(Data2018_filtered3[(Data2018_filtered3['Provider ID'].isin(hosp))])
avgsatis_JH_2018 = Data2018_JH['Score'].mean()

Data2019_JH = pd.DataFrame(Data2019_filtered3[(Data2019_filtered3['Facility ID'].isin(hosp))])
avgsatis_JH_2019 = Data2019_JH['Score'].mean()

Data2021_JH = pd.DataFrame(Data2021_filtered3[(Data2021_filtered3['Facility ID'].isin(hosp))])
avgsatis_JH_2021 = Data2021_JH['Score'].mean()

Data2022_JH = pd.DataFrame(Data2022_filtered3[(Data2022_filtered3['Facility ID'].isin(hosp))])
avgsatis_JH_2022 = Data2022_JH['Score'].mean()

Data2023_JH = pd.DataFrame(Data2023_filtered3[(Data2023_filtered3['Facility ID'].isin(hosp))])
avgsatis_JH_2023 = Data2023_JH['Score'].mean()

print(avgsatis_JH_2015)
print(avgsatis_JH_2018)
print(avgsatis_JH_2019)
print(avgsatis_JH_2021)
print(avgsatis_JH_2022)
print(avgsatis_JH_2023)
# Out:
# 17.8
# 16.2
# 16.0
# 15.4
# 14.8
# 14.8

# %%
df= [['2015',avgsatis_JH_2015 ,Avg_2015],
     ['2018',avgsatis_JH_2018 ,Avg_2018],
     ['2019',avgsatis_JH_2019 ,Avg_2019],
     ['2021',avgsatis_JH_2021 ,Avg_2021],
     ['2022',avgsatis_JH_2022 ,Avg_2022],
     ['2023',avgsatis_JH_2023 ,Avg_2023]]
df
# Out:
# [['2015', 17.8, 16.36299370564486],
#  ['2018', 16.2, 15.53769184856753],
#  ['2019', 16.0, 15.917943277649458],
#  ['2021', 15.4, 15.618971545695684],
#  ['2022', 14.8, 14.948019709349467],
#  ['2023', 14.8, 14.948019709349467]]

# %%
##Step 10: Create data frame for hospitals
#Create data frame for hospitals
dfall = pd.DataFrame(df,columns=['Year','JHH' , 'US HOSP.']).sort_values(by=['Year']).reset_index(drop=True)

# %%
dfall
# Out:
#    Year   JHH   US HOSP.
# 0  2015  17.8  16.362994
# 1  2018  16.2  15.537692
# 2  2019  16.0  15.917943
# 3  2021  15.4  15.618972
# 4  2022  14.8  14.948020
# 5  2023  14.8  14.948020

# %%
dfall.sort_values(by=['US HOSP.']).reset_index(drop=True)
# Out:
#    Year   JHH   US HOSP.
# 0  2022  14.8  14.948020
# 1  2023  14.8  14.948020
# 2  2018  16.2  15.537692
# 3  2021  15.4  15.618972
# 4  2019  16.0  15.917943
# 5  2015  17.8  16.362994

# %%
dfall.describe()
# Out:
#              JHH   US HOSP.
# count   6.000000   6.000000
# mean   15.833333  15.555607
# std     1.127239   0.552417
# min    14.800000  14.948020
# 25%    14.950000  15.095438
# 50%    15.700000  15.578332
# 75%    16.150000  15.843200
# max    17.800000  16.362994

# %%
#fourth spread 

dfall['lower 4th']= 15.095438
dfall['upper 4th']= 15.843200
dfall['Fourth_spreads']= dfall['upper 4th'] - dfall['lower 4th']
dfall
# Out:
#    Year   JHH   US HOSP.  lower 4th  upper 4th  Fourth_spreads
# 0  2015  17.8  16.362994  15.095438    15.8432        0.747762
# 1  2018  16.2  15.537692  15.095438    15.8432        0.747762
# 2  2019  16.0  15.917943  15.095438    15.8432        0.747762
# 3  2021  15.4  15.618972  15.095438    15.8432        0.747762
# 4  2022  14.8  14.948020  15.095438    15.8432        0.747762
# 5  2023  14.8  14.948020  15.095438    15.8432        0.747762

# %%
#calculate UCL & LCL
dfall['UCL']= 15.843200 + 1.5 * 0.747762
dfall['LCL']= 15.843200 - 1.5 * 0.747762
dfall
# Out:
#    Year   JHH   US HOSP.  lower 4th  upper 4th  Fourth_spreads        UCL  \
# 0  2015  17.8  16.362994  15.095438    15.8432        0.747762  16.964843
# 1  2018  16.2  15.537692  15.095438    15.8432        0.747762  16.964843
# 2  2019  16.0  15.917943  15.095438    15.8432        0.747762  16.964843
# 3  2021  15.4  15.618972  15.095438    15.8432        0.747762  16.964843
# 4  2022  14.8  14.948020  15.095438    15.8432        0.747762  16.964843
# 5  2023  14.8  14.948020  15.095438    15.8432        0.747762  16.964843
#
#          LCL
# 0  14.721557
# 1  14.721557
# 2  14.721557
# 3  14.721557
# 4  14.721557
# 5  14.721557

# %%
##Step 19: Plot Control Chart
plt.plot('Year','JHH', data = dfall, marker ='s' ,markerfacecolor = 'blue' , linewidth=1 ,color='blue')
plt.plot('Year','UCL' ,data = dfall, markersize = 0 , color = 'red' , linewidth=1)
plt.plot('Year','LCL',data = dfall, markersize = 0 , color = 'red' , linewidth=1)
plt.legend()
plt.title ('The Johns Hopkins Hospital VS US Best Hospitals Competitors- Rate of readmission after discharge from hospital')
plt.xlabel ('Reporting Year')
plt.ylabel ('Rate')
# Out:
# Text(0, 0.5, 'Rate')
